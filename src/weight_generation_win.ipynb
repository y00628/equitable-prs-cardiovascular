# %%
import pandas as pd
import numpy as np
import subprocess
import os

# %%
phenotypes = pd.read_csv('../data/GD462.GeneQuantRPKM.50FN.samplename.resk10.txt.gz', compression='gzip', sep='\t')
filtered_phenotypes = phenotypes[~phenotypes['Chr'].isin(['X', 'Y', 'M'])]
to_calc = filtered_phenotypes[['TargetID', 'Chr']]
#to_calc = to_calc[to_calc['Chr'].isin(['19', '20', '21'])]
to_calc
# Out:
#                  TargetID Chr
# 23      ENSG00000225267.1  21
# 35      ENSG00000228184.1  21
# 52     ENSG00000126457.15  19
# 55      ENSG00000099804.2  19
# 66      ENSG00000130734.4  19
# ...                   ...  ..
# 23643   ENSG00000142396.4  19
# 23646   ENSG00000125966.7  20
# 23672   ENSG00000254995.4  20
# 23683   ENSG00000232241.1  20
# 23708   ENSG00000243680.1  19
#
# [2092 rows x 2 columns]

# %%
# Define constants for paths and parameters
RSCRIPT_PATH = "Rscript"
FUSION_SCRIPT = "fusion_twas-master/FUSION.compute_weights.R"
BFILE_TEMPLATE = "../data/LDREF_filtered/1000G.EUR.{chr}_filtered"  # Placeholder for chromosome
TMP_DIR = "temp_files"
OUTPUT_DIR = "compute_weights_out"
MODELS = "enet"
PLINK_PATH = "plink.exe"
GCTA_PATH = "fusion_twas-master/gcta_nr_robust.exe"
PHENO_DIR = "../data/gene_expressions"  # Directory with phenotype files
VERBOSE = 2

def compute_weights(gene, chromosome):
    """Runs the FUSION TWAS pipeline for a specific gene and chromosome."""
    # Construct file paths
    bfile = BFILE_TEMPLATE.format(chr=chromosome)
    tmp_file_prefix = os.path.join(TMP_DIR, f"test_chr{chromosome}_{gene}")
    output_path = os.path.join(OUTPUT_DIR, f"{gene}_chr{chromosome}")
    pheno_file = os.path.join(PHENO_DIR, f"{gene}.txt")
    
    # Construct the command
    command = [
        RSCRIPT_PATH, FUSION_SCRIPT,
        "--bfile", bfile,
        "--tmp", tmp_file_prefix,
        "--out", output_path,
        "--models", MODELS,
        "--PATH_plink", PLINK_PATH,
        "--PATH_gcta", GCTA_PATH,
        "--verbose", str(VERBOSE),
        "--pheno", pheno_file
    ]
    clear_command = ['rm', '-rf', 'temp_files/*']

    # Print command for debugging
    print(f"Running: {' '.join(command)}")
    
    # Run the command
    try:
        subprocess.run(command, check=True)
        subprocess.run(clear_command, check=True)
        
    except subprocess.CalledProcessError as e:
        print(f"Error running command for gene {gene}, chromosome {chromosome}: {e}")



for i in to_calc.index:
    gene_data = to_calc.loc[i]
    compute_weights(gene_data['TargetID'], gene_data['Chr'])
# Out:
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000225267.1 --out compute_weights_out\ENSG00000225267.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000225267.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000228184.1 --out compute_weights_out\ENSG00000228184.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000228184.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000126457.15 --out compute_weights_out\ENSG00000126457.15_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000126457.15.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000099804.2 --out compute_weights_out\ENSG00000099804.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000099804.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130734.4 --out compute_weights_out\ENSG00000130734.4_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130734.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000197714.3 --out compute_weights_out\ENSG00000197714.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000197714.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000237484.3 --out compute_weights_out\ENSG00000237484.3_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000237484.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105186.7 --out compute_weights_out\ENSG00000105186.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105186.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000226143.1 --out compute_weights_out\ENSG00000226143.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000226143.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000125846.11 --out compute_weights_out\ENSG00000125846.11_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125846.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000176593.3 --out compute_weights_out\ENSG00000176593.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000176593.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000125651.7 --out compute_weights_out\ENSG00000125651.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125651.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000125503.6 --out compute_weights_out\ENSG00000125503.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125503.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000160213.5 --out compute_weights_out\ENSG00000160213.5_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000160213.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000086967.8 --out compute_weights_out\ENSG00000086967.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000086967.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000177410.8 --out compute_weights_out\ENSG00000177410.8_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000177410.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000215458.4 --out compute_weights_out\ENSG00000215458.4_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000215458.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130810.14 --out compute_weights_out\ENSG00000130810.14_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130810.14.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000243440.1 --out compute_weights_out\ENSG00000243440.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000243440.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000161551.7 --out compute_weights_out\ENSG00000161551.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000161551.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130544.6 --out compute_weights_out\ENSG00000130544.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130544.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000157617.12 --out compute_weights_out\ENSG00000157617.12_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000157617.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000235167.1 --out compute_weights_out\ENSG00000235167.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000235167.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000243494.1 --out compute_weights_out\ENSG00000243494.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000243494.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105676.7 --out compute_weights_out\ENSG00000105676.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105676.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000243927.1 --out compute_weights_out\ENSG00000243927.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000243927.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000167658.9 --out compute_weights_out\ENSG00000167658.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000167658.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000177025.2 --out compute_weights_out\ENSG00000177025.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000177025.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000083828.8 --out compute_weights_out\ENSG00000083828.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000083828.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000230568.1 --out compute_weights_out\ENSG00000230568.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000230568.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000213253.5 --out compute_weights_out\ENSG00000213253.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000213253.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000229833.2 --out compute_weights_out\ENSG00000229833.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000229833.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000161643.7 --out compute_weights_out\ENSG00000161643.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000161643.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105364.8 --out compute_weights_out\ENSG00000105364.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105364.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000100982.6 --out compute_weights_out\ENSG00000100982.6_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000100982.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000223822.2 --out compute_weights_out\ENSG00000223822.2_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000223822.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000101439.4 --out compute_weights_out\ENSG00000101439.4_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000101439.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000125869.4 --out compute_weights_out\ENSG00000125869.4_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125869.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000149474.7 --out compute_weights_out\ENSG00000149474.7_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000149474.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000131351.9 --out compute_weights_out\ENSG00000131351.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000131351.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000249624.3 --out compute_weights_out\ENSG00000249624.3_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000249624.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000156273.10 --out compute_weights_out\ENSG00000156273.10_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000156273.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000129347.14 --out compute_weights_out\ENSG00000129347.14_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000129347.14.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000232220.1 --out compute_weights_out\ENSG00000232220.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000232220.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000088340.10 --out compute_weights_out\ENSG00000088340.10_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000088340.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105671.6 --out compute_weights_out\ENSG00000105671.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105671.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000124103.8 --out compute_weights_out\ENSG00000124103.8_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000124103.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000089057.10 --out compute_weights_out\ENSG00000089057.10_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000089057.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000125730.9 --out compute_weights_out\ENSG00000125730.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125730.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000102575.5 --out compute_weights_out\ENSG00000102575.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000102575.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000083812.5 --out compute_weights_out\ENSG00000083812.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000083812.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000205581.6 --out compute_weights_out\ENSG00000205581.6_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000205581.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000123136.8 --out compute_weights_out\ENSG00000123136.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000123136.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000064961.12 --out compute_weights_out\ENSG00000064961.12_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000064961.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105325.8 --out compute_weights_out\ENSG00000105325.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105325.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000262465.1 --out compute_weights_out\ENSG00000262465.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000262465.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000226763.2 --out compute_weights_out\ENSG00000226763.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000226763.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000241282.1 --out compute_weights_out\ENSG00000241282.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000241282.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000159885.6 --out compute_weights_out\ENSG00000159885.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000159885.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000079805.9 --out compute_weights_out\ENSG00000079805.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000079805.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105327.10 --out compute_weights_out\ENSG00000105327.10_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105327.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000204577.7 --out compute_weights_out\ENSG00000204577.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000204577.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000167785.3 --out compute_weights_out\ENSG00000167785.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000167785.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130203.4 --out compute_weights_out\ENSG00000130203.4_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130203.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000131043.7 --out compute_weights_out\ENSG00000131043.7_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000131043.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000054793.9 --out compute_weights_out\ENSG00000054793.9_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000054793.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000261280.1 --out compute_weights_out\ENSG00000261280.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000261280.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000185792.3 --out compute_weights_out\ENSG00000185792.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000185792.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000012124.9 --out compute_weights_out\ENSG00000012124.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000012124.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104825.12 --out compute_weights_out\ENSG00000104825.12_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104825.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000237202.1 --out compute_weights_out\ENSG00000237202.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000237202.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000259436.1 --out compute_weights_out\ENSG00000259436.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000259436.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104884.9 --out compute_weights_out\ENSG00000104884.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104884.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000071655.9 --out compute_weights_out\ENSG00000071655.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000071655.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104970.6 --out compute_weights_out\ENSG00000104970.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104970.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000069399.7 --out compute_weights_out\ENSG00000069399.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000069399.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000065717.8 --out compute_weights_out\ENSG00000065717.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000065717.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000244274.3 --out compute_weights_out\ENSG00000244274.3_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000244274.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000099875.8 --out compute_weights_out\ENSG00000099875.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000099875.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000101181.12 --out compute_weights_out\ENSG00000101181.12_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000101181.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000249210.1 --out compute_weights_out\ENSG00000249210.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000249210.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104972.10 --out compute_weights_out\ENSG00000104972.10_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104972.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000074181.2 --out compute_weights_out\ENSG00000074181.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000074181.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000011600.4 --out compute_weights_out\ENSG00000011600.4_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000011600.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000205138.2 --out compute_weights_out\ENSG00000205138.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000205138.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000183850.7 --out compute_weights_out\ENSG00000183850.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000183850.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000160336.10 --out compute_weights_out\ENSG00000160336.10_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000160336.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000159917.8 --out compute_weights_out\ENSG00000159917.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000159917.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000233270.1 --out compute_weights_out\ENSG00000233270.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000233270.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104888.4 --out compute_weights_out\ENSG00000104888.4_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104888.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000171124.7 --out compute_weights_out\ENSG00000171124.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000171124.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000175221.7 --out compute_weights_out\ENSG00000175221.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000175221.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000184221.8 --out compute_weights_out\ENSG00000184221.8_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000184221.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000039987.2 --out compute_weights_out\ENSG00000039987.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000039987.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000157551.12 --out compute_weights_out\ENSG00000157551.12_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000157551.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000167460.9 --out compute_weights_out\ENSG00000167460.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000167460.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000179134.8 --out compute_weights_out\ENSG00000179134.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000179134.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000214612.3 --out compute_weights_out\ENSG00000214612.3_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000214612.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000124466.6 --out compute_weights_out\ENSG00000124466.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000124466.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000197134.5 --out compute_weights_out\ENSG00000197134.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000197134.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000230086.1 --out compute_weights_out\ENSG00000230086.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000230086.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130307.6 --out compute_weights_out\ENSG00000130307.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130307.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000154721.9 --out compute_weights_out\ENSG00000154721.9_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000154721.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000141858.7 --out compute_weights_out\ENSG00000141858.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000141858.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000182670.9 --out compute_weights_out\ENSG00000182670.9_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000182670.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000006659.7 --out compute_weights_out\ENSG00000006659.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000006659.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000188629.5 --out compute_weights_out\ENSG00000188629.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000188629.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000125772.7 --out compute_weights_out\ENSG00000125772.7_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125772.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105281.6 --out compute_weights_out\ENSG00000105281.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105281.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000237788.1 --out compute_weights_out\ENSG00000237788.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000237788.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000172070.5 --out compute_weights_out\ENSG00000172070.5_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000172070.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000178386.6 --out compute_weights_out\ENSG00000178386.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000178386.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000249471.2 --out compute_weights_out\ENSG00000249471.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000249471.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000237017.1 --out compute_weights_out\ENSG00000237017.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000237017.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000198646.7 --out compute_weights_out\ENSG00000198646.7_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000198646.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000132823.5 --out compute_weights_out\ENSG00000132823.5_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000132823.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000126266.2 --out compute_weights_out\ENSG00000126266.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000126266.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130811.5 --out compute_weights_out\ENSG00000130811.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130811.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000234906.2 --out compute_weights_out\ENSG00000234906.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000234906.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000126243.3 --out compute_weights_out\ENSG00000126243.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000126243.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000142227.5 --out compute_weights_out\ENSG00000142227.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000142227.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000125863.12 --out compute_weights_out\ENSG00000125863.12_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125863.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000101161.6 --out compute_weights_out\ENSG00000101161.6_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000101161.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000185453.7 --out compute_weights_out\ENSG00000185453.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000185453.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000205673.1 --out compute_weights_out\ENSG00000205673.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000205673.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000167578.11 --out compute_weights_out\ENSG00000167578.11_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000167578.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000130479.5 --out compute_weights_out\ENSG00000130479.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000130479.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000215088.3 --out compute_weights_out\ENSG00000215088.3_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000215088.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000215305.4 --out compute_weights_out\ENSG00000215305.4_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000215305.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000235609.1 --out compute_weights_out\ENSG00000235609.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000235609.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000005007.7 --out compute_weights_out\ENSG00000005007.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000005007.7.txt
# ...
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000095752.1 --out compute_weights_out\ENSG00000095752.1_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000095752.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000101346.6 --out compute_weights_out\ENSG00000101346.6_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000101346.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000259456.1 --out compute_weights_out\ENSG00000259456.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000259456.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000141971.7 --out compute_weights_out\ENSG00000141971.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000141971.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000160310.11 --out compute_weights_out\ENSG00000160310.11_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000160310.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000186842.4 --out compute_weights_out\ENSG00000186842.4_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000186842.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000132819.12 --out compute_weights_out\ENSG00000132819.12_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000132819.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000142002.10 --out compute_weights_out\ENSG00000142002.10_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000142002.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000197016.6 --out compute_weights_out\ENSG00000197016.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000197016.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000197360.4 --out compute_weights_out\ENSG00000197360.4_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000197360.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000090372.7 --out compute_weights_out\ENSG00000090372.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000090372.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000232043.1 --out compute_weights_out\ENSG00000232043.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000232043.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000223891.1 --out compute_weights_out\ENSG00000223891.1_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000223891.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000160299.11 --out compute_weights_out\ENSG00000160299.11_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000160299.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000125812.11 --out compute_weights_out\ENSG00000125812.11_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125812.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000121406.3 --out compute_weights_out\ENSG00000121406.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000121406.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000167637.11 --out compute_weights_out\ENSG00000167637.11_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000167637.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000196172.8 --out compute_weights_out\ENSG00000196172.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000196172.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105131.2 --out compute_weights_out\ENSG00000105131.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105131.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000160216.12 --out compute_weights_out\ENSG00000160216.12_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000160216.12.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000083817.6 --out compute_weights_out\ENSG00000083817.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000083817.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000131055.4 --out compute_weights_out\ENSG00000131055.4_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000131055.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104824.8 --out compute_weights_out\ENSG00000104824.8_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104824.8.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000026036.16 --out compute_weights_out\ENSG00000026036.16_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000026036.16.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000073050.5 --out compute_weights_out\ENSG00000073050.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000073050.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000104938.10 --out compute_weights_out\ENSG00000104938.10_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000104938.10.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000125995.11 --out compute_weights_out\ENSG00000125995.11_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000125995.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000171017.5 --out compute_weights_out\ENSG00000171017.5_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000171017.5.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000128016.3 --out compute_weights_out\ENSG00000128016.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000128016.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000175898.3 --out compute_weights_out\ENSG00000175898.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000175898.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000011332.13 --out compute_weights_out\ENSG00000011332.13_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000011332.13.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.21_filtered --tmp temp_files\test_chr21_ENSG00000242220.1 --out compute_weights_out\ENSG00000242220.1_chr21 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000242220.1.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105402.2 --out compute_weights_out\ENSG00000105402.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105402.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000179909.9 --out compute_weights_out\ENSG00000179909.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000179909.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000205147.3 --out compute_weights_out\ENSG00000205147.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000205147.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000142552.2 --out compute_weights_out\ENSG00000142552.2_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000142552.2.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000228300.7 --out compute_weights_out\ENSG00000228300.7_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000228300.7.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000204604.3 --out compute_weights_out\ENSG00000204604.3_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000204604.3.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000101191.11 --out compute_weights_out\ENSG00000101191.11_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000101191.11.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105383.9 --out compute_weights_out\ENSG00000105383.9_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105383.9.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000105329.4 --out compute_weights_out\ENSG00000105329.4_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000105329.4.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19_filtered --tmp temp_files\test_chr19_ENSG00000181896.6 --out compute_weights_out\ENSG00000181896.6_chr19 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000181896.6.txt
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files\test_chr20_ENSG00000132793.6 --out compute_weights_out\ENSG00000132793.6_chr20 --models enet --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --verbose 2 --pheno ../data/gene_expressions\ENSG00000132793.6.txt
