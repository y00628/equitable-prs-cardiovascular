# %%
import pandas as pd
import numpy as np
import subprocess
import os

# %%
phenotypes = pd.read_csv('../data/std_GD462.GeneQuantRPKM.50FN.samplename.resk10.txt.gz', compression='gzip', sep='\t')
filtered_phenotypes = phenotypes[~phenotypes['Chr'].isin(['X', 'Y', 'M'])]
to_calc = filtered_phenotypes[['TargetID', 'Chr']]
to_calc = to_calc[to_calc['Chr'].isin(['19'])].loc[6532:]
to_calc
# Out:
#                  TargetID Chr
# 6532   ENSG00000105492.10  19
# 6553    ENSG00000105499.8  19
# 6605    ENSG00000186230.5  19
# 6606    ENSG00000126934.6  19
# 6628    ENSG00000186806.3  19
# ...                   ...  ..
# 23604   ENSG00000132017.5  19
# 23627   ENSG00000167676.3  19
# 23638  ENSG00000051128.12  19
# 23643   ENSG00000142396.4  19
# 23708   ENSG00000243680.1  19
#
# [923 rows x 2 columns]

# %%
to_calc[to_calc['TargetID'] == 'ENSG00000105492.10']
to_calc.loc[6532]
# Out:
# TargetID    ENSG00000105492.10
# Chr                         19
# Name: 6532, dtype: object

# %%
# Define constants for paths and parameters
RSCRIPT_PATH = "Rscript"
FUSION_SCRIPT = "fusion_twas-master/FUSION.compute_weights.R"
BFILE_TEMPLATE = "../data/LDREF_filtered/1000G.EUR.{chr}"  # Placeholder for chromosome
TMP_DIR = "temp_files/"
OUTPUT_DIR = "compute_weights_out/chr_{chr}"
MODELS = "enet,lasso"
PLINK_PATH = "plink.exe"
GCTA_PATH = "fusion_twas-master/gcta_nr_robust.exe"
PHENO_DIR = "../data/gene_expressions/chr_{chr}/"  # Directory with phenotype files
VERBOSE = 2
PCS = 10

count = 0
def compute_weights(gene, chromosome):
    """Runs the FUSION TWAS pipeline for a specific gene and chromosome."""
    # Construct file paths
    bfile = BFILE_TEMPLATE.format(chr=chromosome)
    output_dir = OUTPUT_DIR.format(chr=chromosome)
    pheno_dir = PHENO_DIR.format(chr=chromosome)
    
    os.makedirs(output_dir, exist_ok=True)


    tmp_file_prefix = os.path.join(TMP_DIR, f"test_chr{chromosome}_{gene}")
    output_path = os.path.join(output_dir, f"{gene}_chr{chromosome}")
    pheno_file = os.path.join(pheno_dir, f"{gene}.txt")
    covar_path = f"../data/LDREF_filtered_pca/1000G.EUR.{chromosome}_pca_{PCS}.eigenvec"
    

    
    # Construct the command
    command = [
        RSCRIPT_PATH, FUSION_SCRIPT,
        "--bfile", bfile,
        "--tmp", tmp_file_prefix,
        "--out", output_path,
        "--models", MODELS,
        "--PATH_plink", PLINK_PATH,
        "--PATH_gcta", GCTA_PATH,
        "--cov", covar_path,
        "--verbose", str(VERBOSE),
        "--pheno", pheno_file
    ]
    clear_command = ['rm', '-rf', 'temp_files/*']

    # Print command for debugging
    print(f"({count}/{to_calc.shape[0]}) Running: {' '.join(command)}")
    
    # Run the command
    try:
        subprocess.run(command, check=True)
        subprocess.run(clear_command, check=True)
        
    except subprocess.CalledProcessError as e:
        print(f"Error running command for gene {gene}, chromosome {chromosome}: {e}")



for i in to_calc.index:
    count += 1
    gene_data = to_calc.loc[i]
    compute_weights(gene_data['TargetID'], gene_data['Chr'])
# Out:
# (1/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105492.10 --out compute_weights_out/chr_19\ENSG00000105492.10_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105492.10.txt
# (2/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105499.8 --out compute_weights_out/chr_19\ENSG00000105499.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105499.8.txt
# (3/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000186230.5 --out compute_weights_out/chr_19\ENSG00000186230.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000186230.5.txt
# (4/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000126934.6 --out compute_weights_out/chr_19\ENSG00000126934.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000126934.6.txt
# (5/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000186806.3 --out compute_weights_out/chr_19\ENSG00000186806.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000186806.3.txt
# (6/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000183248.5 --out compute_weights_out/chr_19\ENSG00000183248.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000183248.5.txt
# (7/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000196466.5 --out compute_weights_out/chr_19\ENSG00000196466.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000196466.5.txt
# (8/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000141867.11 --out compute_weights_out/chr_19\ENSG00000141867.11_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000141867.11.txt
# (9/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000076826.4 --out compute_weights_out/chr_19\ENSG00000076826.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000076826.4.txt
# (10/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000064545.8 --out compute_weights_out/chr_19\ENSG00000064545.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000064545.8.txt
# (11/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000197813.3 --out compute_weights_out/chr_19\ENSG00000197813.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000197813.3.txt
# (12/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000180458.1 --out compute_weights_out/chr_19\ENSG00000180458.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000180458.1.txt
# (13/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000180884.7 --out compute_weights_out/chr_19\ENSG00000180884.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000180884.7.txt
# (14/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000178229.6 --out compute_weights_out/chr_19\ENSG00000178229.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000178229.6.txt
# (15/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000226800.3 --out compute_weights_out/chr_19\ENSG00000226800.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000226800.3.txt
# (16/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000099785.5 --out compute_weights_out/chr_19\ENSG00000099785.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000099785.5.txt
# (17/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000198003.5 --out compute_weights_out/chr_19\ENSG00000198003.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000198003.5.txt
# (18/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000011478.6 --out compute_weights_out/chr_19\ENSG00000011478.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000011478.6.txt
# (19/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105254.5 --out compute_weights_out/chr_19\ENSG00000105254.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105254.5.txt
# (20/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000062370.9 --out compute_weights_out/chr_19\ENSG00000062370.9_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000062370.9.txt
# (21/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000079385.14 --out compute_weights_out/chr_19\ENSG00000079385.14_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000079385.14.txt
# (22/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000104886.3 --out compute_weights_out/chr_19\ENSG00000104886.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000104886.3.txt
# (23/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000178093.8 --out compute_weights_out/chr_19\ENSG00000178093.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000178093.8.txt
# (24/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000197213.3 --out compute_weights_out/chr_19\ENSG00000197213.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000197213.3.txt
# (25/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105738.5 --out compute_weights_out/chr_19\ENSG00000105738.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105738.5.txt
# (26/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000196081.4 --out compute_weights_out/chr_19\ENSG00000196081.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000196081.4.txt
# (27/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000198551.4 --out compute_weights_out/chr_19\ENSG00000198551.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000198551.4.txt
# (28/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000214046.3 --out compute_weights_out/chr_19\ENSG00000214046.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000214046.3.txt
# (29/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000123815.6 --out compute_weights_out/chr_19\ENSG00000123815.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000123815.6.txt
# (30/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105397.7 --out compute_weights_out/chr_19\ENSG00000105397.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105397.7.txt
# (31/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000174788.4 --out compute_weights_out/chr_19\ENSG00000174788.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000174788.4.txt
# (32/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000125741.3 --out compute_weights_out/chr_19\ENSG00000125741.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000125741.3.txt
# (33/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000130313.1 --out compute_weights_out/chr_19\ENSG00000130313.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000130313.1.txt
# (34/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105438.3 --out compute_weights_out/chr_19\ENSG00000105438.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105438.3.txt
# (35/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000007129.10 --out compute_weights_out/chr_19\ENSG00000007129.10_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000007129.10.txt
# (36/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000132016.6 --out compute_weights_out/chr_19\ENSG00000132016.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000132016.6.txt
# (37/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000186152.6 --out compute_weights_out/chr_19\ENSG00000186152.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000186152.6.txt
# (38/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000235681.1 --out compute_weights_out/chr_19\ENSG00000235681.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000235681.1.txt
# (39/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000073008.8 --out compute_weights_out/chr_19\ENSG00000073008.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000073008.8.txt
# (40/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000126261.5 --out compute_weights_out/chr_19\ENSG00000126261.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000126261.5.txt
# (41/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000156413.7 --out compute_weights_out/chr_19\ENSG00000156413.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000156413.7.txt
# (42/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000173809.11 --out compute_weights_out/chr_19\ENSG00000173809.11_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000173809.11.txt
# (43/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105549.5 --out compute_weights_out/chr_19\ENSG00000105549.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105549.5.txt
# (44/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000213753.4 --out compute_weights_out/chr_19\ENSG00000213753.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000213753.4.txt
# (45/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000127540.4 --out compute_weights_out/chr_19\ENSG00000127540.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000127540.4.txt
# (46/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000087086.7 --out compute_weights_out/chr_19\ENSG00000087086.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000087086.7.txt
# (47/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000196381.3 --out compute_weights_out/chr_19\ENSG00000196381.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000196381.3.txt
# (48/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105708.7 --out compute_weights_out/chr_19\ENSG00000105708.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105708.7.txt
# (49/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000115255.5 --out compute_weights_out/chr_19\ENSG00000115255.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000115255.5.txt
# (50/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000125744.6 --out compute_weights_out/chr_19\ENSG00000125744.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000125744.6.txt
# (51/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000130299.10 --out compute_weights_out/chr_19\ENSG00000130299.10_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000130299.10.txt
# (52/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000010361.7 --out compute_weights_out/chr_19\ENSG00000010361.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000010361.7.txt
# (53/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000188305.2 --out compute_weights_out/chr_19\ENSG00000188305.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000188305.2.txt
# (54/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000104979.3 --out compute_weights_out/chr_19\ENSG00000104979.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000104979.3.txt
# (55/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000262874.1 --out compute_weights_out/chr_19\ENSG00000262874.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000262874.1.txt
# (56/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000108107.7 --out compute_weights_out/chr_19\ENSG00000108107.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000108107.7.txt
# (57/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000221916.2 --out compute_weights_out/chr_19\ENSG00000221916.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000221916.2.txt
# (58/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000185800.5 --out compute_weights_out/chr_19\ENSG00000185800.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000185800.5.txt
# (59/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000060566.7 --out compute_weights_out/chr_19\ENSG00000060566.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000060566.7.txt
# (60/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000115268.3 --out compute_weights_out/chr_19\ENSG00000115268.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000115268.3.txt
# (61/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000179954.7 --out compute_weights_out/chr_19\ENSG00000179954.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000179954.7.txt
# (62/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000239680.1 --out compute_weights_out/chr_19\ENSG00000239680.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000239680.1.txt
# (63/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000129990.8 --out compute_weights_out/chr_19\ENSG00000129990.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000129990.8.txt
# (64/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000131944.4 --out compute_weights_out/chr_19\ENSG00000131944.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000131944.4.txt
# (65/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000160113.3 --out compute_weights_out/chr_19\ENSG00000160113.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000160113.3.txt
# (66/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000160229.6 --out compute_weights_out/chr_19\ENSG00000160229.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000160229.6.txt
# (67/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167749.6 --out compute_weights_out/chr_19\ENSG00000167749.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167749.6.txt
# (68/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000152439.6 --out compute_weights_out/chr_19\ENSG00000152439.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000152439.6.txt
# (69/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105245.4 --out compute_weights_out/chr_19\ENSG00000105245.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105245.4.txt
# (70/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167384.5 --out compute_weights_out/chr_19\ENSG00000167384.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167384.5.txt
# (71/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167654.11 --out compute_weights_out/chr_19\ENSG00000167654.11_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167654.11.txt
# (72/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000179855.5 --out compute_weights_out/chr_19\ENSG00000179855.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000179855.5.txt
# (73/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000176936.2 --out compute_weights_out/chr_19\ENSG00000176936.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000176936.2.txt
# (74/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000177599.7 --out compute_weights_out/chr_19\ENSG00000177599.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000177599.7.txt
# (75/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000171236.6 --out compute_weights_out/chr_19\ENSG00000171236.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000171236.6.txt
# (76/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000242291.1 --out compute_weights_out/chr_19\ENSG00000242291.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000242291.1.txt
# (77/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000104903.3 --out compute_weights_out/chr_19\ENSG00000104903.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000104903.3.txt
# (78/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000233493.2 --out compute_weights_out/chr_19\ENSG00000233493.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000233493.2.txt
# (79/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105640.6 --out compute_weights_out/chr_19\ENSG00000105640.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105640.6.txt
# (80/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000179115.5 --out compute_weights_out/chr_19\ENSG00000179115.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000179115.5.txt
# (81/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000242615.1 --out compute_weights_out/chr_19\ENSG00000242615.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000242615.1.txt
# (82/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000077463.9 --out compute_weights_out/chr_19\ENSG00000077463.9_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000077463.9.txt
# (83/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000160469.9 --out compute_weights_out/chr_19\ENSG00000160469.9_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000160469.9.txt
# (84/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105409.8 --out compute_weights_out/chr_19\ENSG00000105409.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105409.8.txt
# (85/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000197483.6 --out compute_weights_out/chr_19\ENSG00000197483.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000197483.6.txt
# (86/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000076924.6 --out compute_weights_out/chr_19\ENSG00000076924.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000076924.6.txt
# (87/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000079999.8 --out compute_weights_out/chr_19\ENSG00000079999.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000079999.8.txt
# (88/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000254760.1 --out compute_weights_out/chr_19\ENSG00000254760.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000254760.1.txt
# (89/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000206082.4 --out compute_weights_out/chr_19\ENSG00000206082.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000206082.4.txt
# (90/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000125657.2 --out compute_weights_out/chr_19\ENSG00000125657.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000125657.2.txt
# (91/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000095059.10 --out compute_weights_out/chr_19\ENSG00000095059.10_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000095059.10.txt
# (92/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000116017.4 --out compute_weights_out/chr_19\ENSG00000116017.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000116017.4.txt
# (93/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105701.7 --out compute_weights_out/chr_19\ENSG00000105701.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105701.7.txt
# (94/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167618.4 --out compute_weights_out/chr_19\ENSG00000167618.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167618.4.txt
# (95/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000130511.8 --out compute_weights_out/chr_19\ENSG00000130511.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000130511.8.txt
# (96/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105204.8 --out compute_weights_out/chr_19\ENSG00000105204.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105204.8.txt
# (97/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000132004.7 --out compute_weights_out/chr_19\ENSG00000132004.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000132004.7.txt
# (98/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000224916.2 --out compute_weights_out/chr_19\ENSG00000224916.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000224916.2.txt
# (99/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105679.3 --out compute_weights_out/chr_19\ENSG00000105679.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105679.3.txt
# (100/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000077348.3 --out compute_weights_out/chr_19\ENSG00000077348.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000077348.3.txt
# (101/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000213965.2 --out compute_weights_out/chr_19\ENSG00000213965.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000213965.2.txt
# (102/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000178297.7 --out compute_weights_out/chr_19\ENSG00000178297.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000178297.7.txt
# (103/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167815.7 --out compute_weights_out/chr_19\ENSG00000167815.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167815.7.txt
# (104/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000142539.7 --out compute_weights_out/chr_19\ENSG00000142539.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000142539.7.txt
# (105/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000160439.9 --out compute_weights_out/chr_19\ENSG00000160439.9_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000160439.9.txt
# (106/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000226696.1 --out compute_weights_out/chr_19\ENSG00000226696.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000226696.1.txt
# (107/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000090554.6 --out compute_weights_out/chr_19\ENSG00000090554.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000090554.6.txt
# ...
# (111/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000105559.5 --out compute_weights_out/chr_19\ENSG00000105559.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000105559.5.txt
# (112/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167483.11 --out compute_weights_out/chr_19\ENSG00000167483.11_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167483.11.txt
# (113/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000132003.4 --out compute_weights_out/chr_19\ENSG00000132003.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000132003.4.txt
# (114/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000133265.5 --out compute_weights_out/chr_19\ENSG00000133265.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000133265.5.txt
# (115/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000134815.12 --out compute_weights_out/chr_19\ENSG00000134815.12_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000134815.12.txt
# (116/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000180855.10 --out compute_weights_out/chr_19\ENSG00000180855.10_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000180855.10.txt
# (117/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000142046.9 --out compute_weights_out/chr_19\ENSG00000142046.9_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000142046.9.txt
# (118/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000104974.6 --out compute_weights_out/chr_19\ENSG00000104974.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000104974.6.txt
# (119/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000197841.7 --out compute_weights_out/chr_19\ENSG00000197841.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000197841.7.txt
# (120/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000179284.3 --out compute_weights_out/chr_19\ENSG00000179284.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000179284.3.txt
# (121/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000240418.1 --out compute_weights_out/chr_19\ENSG00000240418.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000240418.1.txt
# (122/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000034063.7 --out compute_weights_out/chr_19\ENSG00000034063.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000034063.7.txt
# (123/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000166398.5 --out compute_weights_out/chr_19\ENSG00000166398.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000166398.5.txt
# (124/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000242779.1 --out compute_weights_out/chr_19\ENSG00000242779.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000242779.1.txt
# (125/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167232.8 --out compute_weights_out/chr_19\ENSG00000167232.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167232.8.txt
# (126/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000250067.3 --out compute_weights_out/chr_19\ENSG00000250067.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000250067.3.txt
# (127/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000186529.7 --out compute_weights_out/chr_19\ENSG00000186529.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000186529.7.txt
# (128/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000244482.3 --out compute_weights_out/chr_19\ENSG00000244482.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000244482.3.txt
# (129/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000248406.1 --out compute_weights_out/chr_19\ENSG00000248406.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000248406.1.txt
# (130/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000197928.4 --out compute_weights_out/chr_19\ENSG00000197928.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000197928.4.txt
# (131/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000225975.1 --out compute_weights_out/chr_19\ENSG00000225975.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000225975.1.txt
# (132/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000099331.7 --out compute_weights_out/chr_19\ENSG00000099331.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000099331.7.txt
# (133/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000225373.1 --out compute_weights_out/chr_19\ENSG00000225373.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000225373.1.txt
# (134/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000196437.5 --out compute_weights_out/chr_19\ENSG00000196437.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000196437.5.txt
# (135/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000188785.6 --out compute_weights_out/chr_19\ENSG00000188785.6_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000188785.6.txt
# (136/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000242852.2 --out compute_weights_out/chr_19\ENSG00000242852.2_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000242852.2.txt
# (137/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000167555.8 --out compute_weights_out/chr_19\ENSG00000167555.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000167555.8.txt
# (138/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000188321.7 --out compute_weights_out/chr_19\ENSG00000188321.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000188321.7.txt
# (139/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000166704.7 --out compute_weights_out/chr_19\ENSG00000166704.7_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000166704.7.txt
# (140/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000104872.5 --out compute_weights_out/chr_19\ENSG00000104872.5_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000104872.5.txt
# (141/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000181035.8 --out compute_weights_out/chr_19\ENSG00000181035.8_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000181035.8.txt
# (142/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000197951.3 --out compute_weights_out/chr_19\ENSG00000197951.3_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000197951.3.txt
# (143/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000104915.9 --out compute_weights_out/chr_19\ENSG00000104915.9_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000104915.9.txt
# (144/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000127528.4 --out compute_weights_out/chr_19\ENSG00000127528.4_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000127528.4.txt
# (145/923) Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.19 --tmp temp_files/test_chr19_ENSG00000099795.1 --out compute_weights_out/chr_19\ENSG00000099795.1_chr19 --models enet,lasso --PATH_plink plink.exe --PATH_gcta fusion_twas-master/gcta_nr_robust.exe --cov ../data/LDREF_filtered_pca/1000G.EUR.19_pca_10.eigenvec --verbose 2 --pheno ../data/gene_expressions/chr_19/ENSG00000099795.1.txt
