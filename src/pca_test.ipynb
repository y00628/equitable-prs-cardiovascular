# %%
import pandas as pd

# %%
pd.read_csv('../data/LDREF_filtered_pca/1000G.EUR.19_pca.eigenvec', sep=' ', header=None)
# Out:
#           0        1         2         3         4         5         6   \
# 0    HG00097  HG00097 -0.009838  0.008166 -0.044630 -0.000826  0.010395
# 1    HG00099  HG00099 -0.013659  0.021458  0.040278  0.020276 -0.039411
# 2    HG00101  HG00101  0.032945 -0.040156 -0.001599 -0.016824  0.048729
# 3    HG00102  HG00102  0.029068 -0.057894  0.039765  0.055994  0.001498
# 4    HG00103  HG00103  0.004208 -0.010928  0.031181  0.010063  0.093064
# ..       ...      ...       ...       ...       ...       ...       ...
# 338  NA20814  NA20814 -0.000812  0.050509 -0.012216 -0.004192 -0.010313
# 339  NA20815  NA20815 -0.079588 -0.084876  0.067305 -0.081319 -0.001046
# 340  NA20819  NA20819 -0.038020  0.003665 -0.014637  0.022903  0.022573
# 341  NA20826  NA20826 -0.078384  0.042333 -0.032876 -0.020893  0.010228
# 342  NA20828  NA20828 -0.061281  0.045683  0.047907 -0.111054  0.021912
#
#            7         8         9   ...        12        13        14  \
# ...
