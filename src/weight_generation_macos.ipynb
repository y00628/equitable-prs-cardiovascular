# %%
import pandas as pd
import numpy as np
import subprocess
import os

# %%
phenotypes = pd.read_csv('../data/GD462.GeneQuantRPKM.50FN.samplename.resk10.txt.gz', compression='gzip', sep='\t')
filtered_phenotypes = phenotypes[~phenotypes['Chr'].isin(['X', 'Y', 'M'])]
to_calc = filtered_phenotypes[['TargetID', 'Chr']]
to_calc = to_calc[to_calc['Chr'].isin(['20'])]
to_calc
# Out:
#                  TargetID Chr
# 149     ENSG00000226143.1  20
# 151    ENSG00000125846.11  20
# 253     ENSG00000177410.8  20
# 397     ENSG00000235167.1  20
# 479     ENSG00000230568.1  20
# ...                   ...  ..
# 23561   ENSG00000215063.3  20
# 23613   ENSG00000124228.9  20
# 23646   ENSG00000125966.7  20
# 23672   ENSG00000254995.4  20
# 23683   ENSG00000232241.1  20
#
# [561 rows x 2 columns]

# %%
# Define constants for paths and parameters
RSCRIPT_PATH = "Rscript"
FUSION_SCRIPT = "fusion_twas-master/FUSION.compute_weights.R"
BFILE_TEMPLATE = "../data/LDREF_filtered/1000G.EUR.{chr}_filtered"  # Placeholder for chromosome
TMP_DIR = "temp_files"
OUTPUT_DIR = "compute_weights_out"
MODELS = "enet"
PLINK_PATH = "./plink"
GCTA_PATH = "fusion_twas-master/gcta"
PHENO_DIR = "../data/gene_expressions"  # Directory with phenotype files
VERBOSE = 2

def compute_weights(gene, chromosome):
    """Runs the FUSION TWAS pipeline for a specific gene and chromosome."""
    # Construct file paths
    bfile = BFILE_TEMPLATE.format(chr=chromosome)
    tmp_file_prefix = os.path.join(TMP_DIR, f"test_chr{chromosome}_{gene}")
    output_path = os.path.join(OUTPUT_DIR, f"{gene}_chr{chromosome}")
    pheno_file = os.path.join(PHENO_DIR, f"{gene}.txt")
    
    # Construct the command
    command = [
        RSCRIPT_PATH, FUSION_SCRIPT,
        "--bfile", bfile,
        "--tmp", tmp_file_prefix,
        "--out", output_path,
        "--models", MODELS,
        "--PATH_plink", PLINK_PATH,
        "--PATH_gcta", GCTA_PATH,
        "--verbose", str(VERBOSE),
        "--pheno", pheno_file
    ]
    clear_command = ['rm', '-rf', 'temp_files/*']

    # Print command for debugging
    print(f"Running: {' '.join(command)}")
    
    # Run the command
    try:
        subprocess.run(command, check=True)
        subprocess.run(clear_command, check=True)
        
    except subprocess.CalledProcessError as e:
        print(f"Error running command for gene {gene}, chromosome {chromosome}: {e}")



for i in to_calc.index:
    gene_data = to_calc.loc[i]
    compute_weights(gene_data['TargetID'], gene_data['Chr'])
# Out:
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000226143.1 --out compute_weights_out/ENSG00000226143.1_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000226143.1.txt
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000226143.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000226143.1.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000226143.1
#   --pheno ../data/gene_expressions/ENSG00000226143.1.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000226143.1.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000226143.1.bed +
# temp_files/test_chr20_ENSG00000226143.1.bim +
# temp_files/test_chr20_ENSG00000226143.1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00
log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000125869.4
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000125869.4
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000125869.4.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000125869.4.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000125869.4.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000149474.7 --out compute_weights_out/ENSG00000149474.7_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000149474.7.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000125869.4 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000149474.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000149474.7.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000149474.7
#   --pheno ../data/gene_expressions/ENSG00000149474.7.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000149474.7.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000149474.7.bed +
# temp_files/test_chr20_ENSG00000149474.7.bim +
# temp_files/test_chr20_ENSG00000149474.7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000149474.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000149474.7
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000149474.7
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000149474.7.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000149474.7.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000149474.7.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000088340.10 --out compute_weights_out/ENSG00000088340.10_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000088340.10.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000149474.7 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000088340.10.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000088340.10.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000088340.10
#   --pheno ../data/gene_expressions/ENSG00000088340.10.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000088340.10.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000088340.10.bed +
# temp_files/test_chr20_ENSG00000088340.10.bim +
# temp_files/test_chr20_ENSG00000088340.10.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000088340.10.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000088340.10
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000088340.10
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000088340.10.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000088340.10.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000088340.10.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000124103.8 --out compute_weights_out/ENSG00000124103.8_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000124103.8.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000088340.10 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000124103.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000124103.8.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000124103.8
#   --pheno ../data/gene_expressions/ENSG00000124103.8.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000124103.8.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000124103.8.bed +
# temp_files/test_chr20_ENSG00000124103.8.bim +
# temp_files/test_chr20_ENSG00000124103.8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000124103.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000124103.8
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000124103.8
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000124103.8.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000124103.8.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000124103.8.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000089057.10 --out compute_weights_out/ENSG00000089057.10_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000089057.10.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000124103.8 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000089057.10.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000089057.10.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000089057.10
#   --pheno ../data/gene_expressions/ENSG00000089057.10.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000089057.10.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000089057.10.bed +
# temp_files/test_chr20_ENSG00000089057.10.bim +
# temp_files/test_chr20_ENSG00000089057.10.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000089057.10.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000089057.10
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000089057.10
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000089057.10.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000089057.10.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000089057.10.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000131043.7 --out compute_weights_out/ENSG00000131043.7_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000131043.7.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000089057.10 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000131043.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000131043.7.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000131043.7
#   --pheno ../data/gene_expressions/ENSG00000131043.7.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000131043.7.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000131043.7.bed +
# temp_files/test_chr20_ENSG00000131043.7.bim +
# temp_files/test_chr20_ENSG00000131043.7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000131043.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000131043.7
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000131043.7
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000131043.7.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000131043.7.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000131043.7.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000054793.9 --out compute_weights_out/ENSG00000054793.9_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000054793.9.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000131043.7 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000054793.9.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000054793.9.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000054793.9
#   --pheno ../data/gene_expressions/ENSG00000054793.9.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000054793.9.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000054793.9.bed +
# temp_files/test_chr20_ENSG00000054793.9.bim +
# ...
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000215063.3.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000215063.3
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000215063.3
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000215063.3.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000215063.3.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000215063.3.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000124228.9 --out compute_weights_out/ENSG00000124228.9_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000124228.9.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000215063.3 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000124228.9.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000124228.9.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000124228.9
#   --pheno ../data/gene_expressions/ENSG00000124228.9.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000124228.9.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000124228.9.bed +
# temp_files/test_chr20_ENSG00000124228.9.bim +
# temp_files/test_chr20_ENSG00000124228.9.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000124228.9.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000124228.9
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000124228.9
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000124228.9.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000124228.9.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000124228.9.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000125966.7 --out compute_weights_out/ENSG00000125966.7_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000125966.7.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000124228.9 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000125966.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000125966.7.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000125966.7
#   --pheno ../data/gene_expressions/ENSG00000125966.7.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000125966.7.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000125966.7.bed +
# temp_files/test_chr20_ENSG00000125966.7.bim +
# temp_files/test_chr20_ENSG00000125966.7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000125966.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000125966.7
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000125966.7
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000125966.7.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000125966.7.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000125966.7.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000254995.4 --out compute_weights_out/ENSG00000254995.4_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000254995.4.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000125966.7 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000254995.4.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000254995.4.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000254995.4
#   --pheno ../data/gene_expressions/ENSG00000254995.4.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000254995.4.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000254995.4.bed +
# temp_files/test_chr20_ENSG00000254995.4.bim +
# temp_files/test_chr20_ENSG00000254995.4.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000254995.4.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000254995.4
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000254995.4
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000254995.4.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000254995.4.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000254995.4.grm.id .
# Running: Rscript fusion_twas-master/FUSION.compute_weights.R --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered --tmp temp_files/test_chr20_ENSG00000232241.1 --out compute_weights_out/ENSG00000232241.1_chr20 --models enet --PATH_plink ./plink --PATH_gcta fusion_twas-master/gcta --verbose 2 --pheno ../data/gene_expressions/ENSG00000232241.1.txt
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000254995.4 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000232241.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../data/LDREF_filtered/1000G.EUR.20_filtered
#   --keep ../data/gene_expressions/ENSG00000232241.1.txt
#   --make-bed
#   --out temp_files/test_chr20_ENSG00000232241.1
#   --pheno ../data/gene_expressions/ENSG00000232241.1.txt
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000232241.1.nosex .
# 343 phenotype values present after --pheno.
# --keep: 343 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to temp_files/test_chr20_ENSG00000232241.1.bed +
# temp_files/test_chr20_ENSG00000232241.1.bim +
# temp_files/test_chr20_ENSG00000232241.1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# ### Estimating heritability
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to temp_files/test_chr20_ENSG00000232241.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile temp_files/test_chr20_ENSG00000232241.1
#   --make-grm-bin
#   --out temp_files/test_chr20_ENSG00000232241.1
#
# 24576 MB RAM detected; reserving 12288 MB for main workspace.
# 31101 variants loaded from .bim file.
# 343 people (0 males, 0 females, 343 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to temp_files/test_chr20_ENSG00000232241.1.nosex .
# 343 phenotype values loaded from .fam.
# Using up to 9 threads (change this with --threads).
# Before main variant filters, 343 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is exactly 1.
# 31101 variants and 343 people pass filters and QC.
# Phenotype data is quantitative.
# Relationship matrix calculation complete.
# Relationship matrix written to temp_files/test_chr20_ENSG00000232241.1.grm.bin
# , and IDs written to temp_files/test_chr20_ENSG00000232241.1.grm.id .
# sh: fusion_twas-master/gcta: No such file or directory
# temp_files/test_chr20_ENSG00000232241.1 does not exist, likely GCTA could not converge, skipping gene
# Warning message:
# In system(arg, ignore.stdout = SYS_PRINT, ignore.stderr = SYS_PRINT) :
#   error in running command
